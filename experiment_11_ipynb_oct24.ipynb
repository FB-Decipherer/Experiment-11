# %% [markdown]
# <a href="https://colab.research.google.com/github/FB-Decipherer/Experiment-11/blob/main/experiment_11_ipynb_oct24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import datetime
import re

from google.colab import drive
drive.mount('/content/drive')

input_dir = '/content/drive/MyDrive/Word Cipher Decode/input'
input_file_name = 'outer text minus footer.txt'
input_file_path = input_dir + input_file_name

input_file_path = '/content/drive/MyDrive/Word Cipher Decode/input/outer text minus footer.txt'

with open(input_file_path, 'r') as f:
    outer_text = f.read()

    # ---------------------------
    guide_words = ["fortune", "reputation", "honor", "nature"]
    color = 'red'

    for item in guide_words:
        replacement = "<span style='color:" + color + ";font-weight:bold;'>" + item + "</span>"
        outer_text = re.sub(item, replacement, outer_text, flags=re.IGNORECASE)
    # ---------------------------

    key_words = ["DrOwen"]
    color = 'green'

    for item in key_words:
        replacement = "<span style='color:" + color + ";font-weight:bold;'>" + item + "</span>"
        outer_text = re.sub(item, replacement, outer_text, flags=re.IGNORECASE)
    # ---------------------------
    key_words = ["inflammation","heat"]
    color = 'Chartreuse'

    for item in key_words:
        replacement = "<span style='color:" + color + ";font-weight:bold;'>" + item + "</span>"
        outer_text = re.sub(item, replacement, outer_text, flags=re.IGNORECASE)
    # ---------------------------

    inner_phrases = [
    "in the writers opinion",
    "it would have been better for",
    "the discoverer of the cipher",
    "to have made public his cipher method",
    "at the start",
    "and thus have forestalled criticism",
    "could as he of course stoutly maintains",
    "prove the existence of his method to any impartial mind beyond a doubt",
    "he would have run",
    "a great risk",
    "that of having some other decipherer using the",
    "disclosed method bring out rival books",
    "he should however",
    "have taken it",
    "Most people disbelieve in",
    "so thoroughly as to give their words and manners every appearance of personality, but many thoughtful readers will be more fair minded"
                    ]
    color = 'Orange'
    for item in inner_phrases:
        replacement = "<span style='color:" + color + ";font-weight:bold;background:' + color + '>" + item + "</span>"
        outer_text = re.sub(item, replacement, outer_text, flags=re.IGNORECASE)
        #print(item)
    key_words = ["method"]
    color = 'blue'

    for item in key_words:
        replacement = "<span style='color:" + color + ";font-weight:bold;'>" + item + "</span>"
        outer_text = re.sub(item, replacement, outer_text, flags=re.IGNORECASE)
    # ---------------------------

    key_words = ["results"]
    color = 'Olive'

    for item in key_words:
        replacement = "<span style='color:" + color + ";font-weight:bold;'>" + item + "</span>"
        outer_text = re.sub(item, replacement, outer_text, flags=re.IGNORECASE)

    key_words = ["key-word"]
    color = 'DarkBlue'

    for item in key_words:
        replacement = "<span style='color:" + color + ";font-weight:bold;'>" + item + "</span>"
        outer_text = re.sub(item, replacement, outer_text, flags=re.IGNORECASE)

    key_words = ["Bacon"]
    color = 'Pink'

    for item in key_words:
        replacement = "<span style='color:" + color + ";font-weight:bold;'>" + item + "</span>"
        outer_text = re.sub(item, replacement, outer_text, flags=re.IGNORECASE)

    # ---------------------------
    key_words = ["illustrat"]
    color = 'Cyan'

    for item in key_words:
        replacement = "<span style='color:" + color + ";font-weight:bold;'>" + item + "</span>"
        outer_text = re.sub(item, replacement, outer_text, flags=re.IGNORECASE)
    # ---------------------------
    key_words = ["concealed"]
    color = 'Orange'

    for item in key_words:
        replacement = "<span style='color:" + color + ";font-weight:bold;'>" + item + "</span>"
        outer_text = re.sub(item, replacement, outer_text, flags=re.IGNORECASE)
        # ---------------------------
    key_words = ["statement"]
    color = 'Indigo'

    for item in key_words:
        replacement = "<span style='color:" + color + ";font-weight:bold;'>" + item + "</span>"
        outer_text = re.sub(item, replacement, outer_text, flags=re.IGNORECASE)

        # ---------------------------
    key_words = ["faith"]
    color = 'Indigo'

    for item in key_words:
        replacement = "<span style='color:" + color + ";font-weight:bold;'>" + item + "</span>"
        outer_text = re.sub(item, replacement, outer_text, flags=re.IGNORECASE)
        # ---------------------------
    key_words = ["Detroit"]
    color = 'Indigo'

    for item in key_words:
        replacement = "<span style='color:" + color + ";font-weight:bold;'>" + item + "</span>"
        outer_text = re.sub(item, replacement, outer_text, flags=re.IGNORECASE)
    # ---------------------------


now = datetime.datetime.now()

output_dir = '/content/drive/MyDrive/Word Cipher/output/millet html output/'

output_file_name = now.strftime('%Y-%m-%d_%H-%M-%S.html')
output_file_path = '/content/drive/MyDrive/Word Cipher Decode/output/' + output_file_name


with open(output_file_path, 'w') as file:
    file.write(outer_text)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
